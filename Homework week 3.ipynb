# %%
# An algorithm is a series of steps to solve a problem at hand. 
'Variable names may not start with the following characters: ! and 3'
'a Semantic error is a code that is grammatically correct but does not make any sense; it does not produce the expected results'
'The firt rule of coding/debugging is: **Complexity is the enemy of efficiency!'
## five python reserved words: Non, else, nonlocal, except, and finally

# %%
""" Jean favorite's food is
rice and bean. My dream job is
program manager"""

x = "Hello, Jacksonville"
a = 27
b = 17.8
soccerplayersList = ["Messi", "Mbappe", "Haaland", "Osimen", "Rashford"]
d = True
print("The length of a is ... ", len(x))
print ("element at the index 3 is: " , x[3])
savvy = "Learning Data Analytics and Python is Awesome!"
print(savvy[5:23])
e = savvy.replace("Awesome", "Great")
print(e)

if "Python" in savvy:
	print("Yes, 'Python' is present.")

name, age, lenght = "Jean", 47, "6ft"
minibio = "My name is " + name + ", I am " + age + " years old, I am " + lenght + " (tall) and (so} old today."
print(minibio)
j = float(47)
print(j)

soccerList = ["Haaland", "Manchester City", 40 , "goals", "Greatest", "forward"]
soccerList[0:2] = ["Messi", "Barcelona"]
print(" replaced [0:2] ... ", soccerList)

soccerList.append("Argentina")
print("New list ... ", soccerList)

soccerList.append(29)
print("New list ... ", soccerList)

listLength = len(soccerList)
print("Size of the List = ", listLength)
newsoccerList = soccerList[0:3]
print(newsoccerList)

soccerList.extend(newsoccerList)
print("Extended soccerList ... ", soccerList)

simList = ["Walmart", "Publix", "Rowes", "WinnDixie", "Aldy"]
simList.sort()
print("Sorted simList - default ", simList)

simList2 = simList.copy()
print('Copied List:', simList2)

list4 = newsoccerList + simList2
print("New added list ...", list4)

savvytup = 'army', 'navy', 'space', 'airforce' , 'marines'
savvytup1 = savvytup * 3
print("savvytup1 ...", savvytup1)

print ("element at the index 11 is: " , savvytup1[11])

sorted(savvytup1)
print("Sorted savvytup1 - default ", savvytup1)

savvytup2 = savvytup1[0:4]
print(savvytup2)

(army, navy, space, airforce) = savvytup2
print(army)
print(navy)
print(space)
print(airforce)

savvytup3 = (50,)
print(savvytup3)

savvytup4 = savvytup1 + savvytup2
print("savvytup4 ...", savvytup4)

birdSet = {"eagles", "falcons", "seahawks"}
fruitList = ["banana", "cherry", "strawberry"]
birdSet.update(fruitList)
print("\nupdated Set ... ", birdSet)

birdSet.add("toyota")
print("birdSet ... ", birdSet)

variabSet = {"27", "nfl", "mlb", "43.2"}
unionbirdSet = birdSet.union(variabSet)
print("\nUnited sets ...\n", unionbirdSet)

variabSet.pop()
print("reduced variabSet ... ", variabSet)

birdSet.clear()
print("cleared set ... ", birdSet)

unionbirdSet.remove("banana")
unionbirdSet.discard("nfl")
print("reduced unionbirdSet ... ", unionbirdSet)

week3Dict = {
    "brand": "samsung",
    "model": "galaxy",
    "flip": False,
    "year": 2020,
 "colors": ["white", "gold", "black"],
    "weight": "2.5 lbs"}
print(week3Dict['brand'])

week3Dict.update({"brand": "jean"})
print(week3Dict)

week3Dict.update({"color": "blue"})
print(week3Dict)

week3Dict["users"]= ["teachers","students", "firefighters"]
print(week3Dict)
print(week3Dict.keys())
print(week3Dict.values())

week3Dict2 = week3Dict.copy()
print("week3Dict2: ", week3Dict2)

element = week3Dict2.pop('weight')
print(week3Dict2)

week3Dict2.clear()
print(week3Dict2)
# Out:
# The length of a is ...  19
# element at the index 4 is:  o
# ing Data Analytics
# Learning Data Analytics and Python is Great!
# Yes, 'Python' is present.
# My name is Jean, I am 47 years old, I am 6ft (tall) and (so} old today.
# 47.0
#  replaced [0:2] ...  ['Messi', 'Barcelona', 40, 'goals', 'Greatest', 'forward']
# New list ...  ['Messi', 'Barcelona', 40, 'goals', 'Greatest', 'forward', 'Argentina']
# New list ...  ['Messi', 'Barcelona', 40, 'goals', 'Greatest', 'forward', 'Argentina', 29]
# Size of the List =  8
# ['Messi', 'Barcelona', 40]
# Extended soccerList ...  ['Messi', 'Barcelona', 40, 'goals', 'Greatest', 'forward', 'Argentina', 29, 'Messi', 'Barcelona', 40]
# Sorted simList - default  ['Aldy', 'Publix', 'Rowes', 'Walmart', 'WinnDixie']
# Copied List: ['Aldy', 'Publix', 'Rowes', 'Walmart', 'WinnDixie']
# New added list ... ['Messi', 'Barcelona', 40, 'Aldy', 'Publix', 'Rowes', 'Walmart', 'WinnDixie']
# ...
